# %%
import openai
import os
import json
from collections import defaultdict

# %%
llm_config = {
    "config_list": [
        {
            "model": "gpt-4o-mini",
            "api_key": os.environ.get("OPENAI_API_KEY")
        }
    ]
}

# Configure OpenAI API key
openai.api_key = llm_config["config_list"][0]["api_key"]

# %%
input_directory =  "/Users/yifeitao/Desktop/ds-discovery/small_set_texts"

# %%
with open('/Users/yifeitao/Desktop/ds-discovery/simple_large_schema.json', 'r') as schema_file:
    json_schema = json.load(schema_file)

# %%
import os
print(os.environ.get("OPENAI_API_KEY"))
# Out:
# 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
